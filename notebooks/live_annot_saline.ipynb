# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# let's silence all the annoying Future warnings from Pandas:
import pandas as pd

# %%
np.random.seed(seed=42)

# %%
adata = sc.read_h5ad("./saline.h5ad")

# %% [markdown]
# PTPRC P2RY12 PAX6 SFRP1 OLIG1 PDGRFA COL20A1 PMP2 NEUROD2 RBFOX1 GAD1 PDE4DIP GFAP AQP4 SLCO1C1
#
# interneurons (wikipedia):
#
# - SOM (Sst in mouse)
# - pvalb
# - VIP
# - cck

# %%
keep = adata.var.index.str.contains("Slc17a7", case=False)
adata.var.index[keep]
# Out:
# Index(['Slc17a7'], dtype='object')

# %%
sc.pl.umap(adata, color=["Slc17a7", "Pdgfra"], cmap="magma_r", ncols=2, sort_order=True)

# %%
sc.pl.umap(adata, color=["Grik1", "Grik2", "Grik3", "Grik4", "Grik5"], cmap="magma_r", ncols=2, sort_order=True)

# %%
sc.pl.umap(adata, color=["Aqp4", "Gfap", "Slco1c1", "Slco1c1"], cmap="magma_r", ncols=2, sort_order=True)

# %%
sc.pl.umap(adata, color=["Sst", "Pvalb", "Vip", "Cck"], cmap="magma_r", ncols=2, sort_order=True)

# %%
sc.pl.umap(adata, color=["Gad1", "Gad2"], cmap="magma_r")

# %%
# microglia
sc.pl.umap(adata, color=["Ptprc", "P2ry12"], cmap="magma_r")

# %%
# smooth muscle cells?
sc.pl.umap(adata, color=["Rgs5", "Flt1"], cmap="magma_r")

# %%
sc.tl.leiden(adata, resolution=0.8)

# %%
sc.pl.umap(adata, color="leiden", legend_loc="on data")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ascc24/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.tl.dendrogram(adata, groupby="leiden")

# %%
markers = ["Slc17a7",  "Gfap", "Aqp4", "Slco1c1", "Sst", "Pvalb", "Vip", "Cck", "Gad1", "Gad2", "Ptprc", "P2ry12", "Pdgfra", "Lamp5", "Mog", "Rgs5", "Flt1", "Pecam1", "Rorb", "Cx3cr1"]

# %%
sc.pl.dotplot(adata, groupby="leiden", var_names=markers, 
              swap_axes=True, cmap="magma_r", dendrogram=True)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ascc24/lib/python3.9/site-packages/scanpy/plotting/_dotplot.py:747: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
my_order = ["7", "9", "11"]
